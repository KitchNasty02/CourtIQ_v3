# %% [markdown]
# <a href="https://colab.research.google.com/github/KitchNasty02/CourtIQ_v3/blob/main/notebooks/simclr_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dependencies

# %% [markdown]
# Install Libraries

# %%
# !pip install pytorch_metric_learning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 4.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Mount Google Drive to Frames

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

location = '/content/drive/MyDrive/Projects/CourtIQ/'

sys.path.append(os.path.abspath(location))

# %% [markdown]
# # Dataset

# %%
from train_simclr_mobilevit import main
main()
# Out:
# Training on cpu
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4132377293.py in <cell line: 0>()
#       1 from train_simclr_mobilevit import main
# ----> 2 main()
#
# /content/drive/MyDrive/Projects/CourtIQ/train_simclr_mobilevit.py in main()
#      41
#      42     transform = TennisAugment(image_size=256)
# ---> 43     dataset = SimCLRDataset('/content/drive/MyDrive/Projects/CourtIQ/frames', transform)
#      44
#      45     loader = DataLoader(
#
# /content/drive/MyDrive/Projects/CourtIQ/data/simclr_dataset.py in __init__(self, image_dir, transform)
#      11         self.image_paths = [
#      12             os.path.join(image_dir, fname)
# ---> 13             for fname in sorted(os.listdir(image_dir))
#      14             if fname.lower().endswith(('.jpg', '.jpeg', '.png'))
#      15         ]
#
# ...

# %%
from data.simclr_dataset import SimCLRDataset
from data.tennis_augment import TennisAugment

dataset = SimCLRDataset(
    '/content/drive/MyDrive/Projects/CourtIQ/frames',
    TennisAugment(256)
)

print(f"Number of images found: {len(dataset)}")

# Grab one sample
v1, v2 = dataset[0]
print(v1.shape, v2.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3071709182.py in <cell line: 0>()
#       2 from data.tennis_augment import TennisAugment
#       3
# ----> 4 dataset = SimCLRDataset(
#       5     '/content/drive/MyDrive/Projects/CourtIQ/frames',
#       6     TennisAugment(256)
#
# /content/drive/MyDrive/Projects/CourtIQ/data/simclr_dataset.py in __init__(self, image_dir, transform)
#      17             # for f in files:
#      18             #   if f.lower().endswith(('.jpg', '.jpeg', '.png')):
# ---> 19             #       self.image_paths.append(os.path.join(root, f))
#      20
#      21         # raise error if no frames exist in folder
#
# RuntimeError: No images found in /content/drive/MyDrive/Projects/CourtIQ/frames
