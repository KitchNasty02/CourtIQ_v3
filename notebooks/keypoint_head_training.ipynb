# %% [markdown]
# Dependencies

# %%
# !pip install pytorch_metric_learning albumentations
# Out:
# Requirement already satisfied: pytorch_metric_learning in /usr/local/lib/python3.12/dist-packages (2.9.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch_metric_learning) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pytorch_metric_learning) (1.6.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_metric_learning) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pytorch_metric_learning) (4.67.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (3.24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->pytorch_metric_learning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.6.0->pytorch_metric_learning) (1.3.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pytorch_metric_learning) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pytorch_metric_learning) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->pytorch_metric_learning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->pytorch_metric_learning) (3.0.3)

# %% [markdown]
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

location = '/content/drive/MyDrive/Projects/CourtIQ/'

sys.path.append(os.path.abspath(location))

# %% [markdown]
# Unzip dataset

# %%
# !unzip -u /content/drive/MyDrive/Projects/CourtIQ/tennis_court_det_dataset.zip -d /content/data
# Out:
# Archive:  /content/drive/MyDrive/Projects/CourtIQ/tennis_court_det_dataset.zip

# %% [markdown]
# Train

# %%
from train_keypoint_head import main
main()
# Out:
# Training on cuda
# Stride:  32
# Loaded metrics from epoch 1-50
# Last PCK: 0.8036
# Training samples: 6630
# Validation samples: 2211
# Epoch [51] Batch 0/104 | Loss: 0.00413588
# Epoch [51] Batch 50/104 | Loss: 0.00489097
# Epoch [51] Batch 100/104 | Loss: 0.00463237
# Epoch [51/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8034 (80.34%)
#   Val Avg Dist:    77.26 pixels
#
# Epoch [52] Batch 0/104 | Loss: 0.00398484
# Epoch [52] Batch 50/104 | Loss: 0.00499158
# Epoch [52] Batch 100/104 | Loss: 0.00457652
# Epoch [52/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8008 (80.08%)
#   Val Avg Dist:    77.77 pixels
#
# Epoch [53] Batch 0/104 | Loss: 0.00424574
# Epoch [53] Batch 50/104 | Loss: 0.00473773
# Epoch [53] Batch 100/104 | Loss: 0.00458529
# Epoch [53/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8041 (80.41%)
#   Val Avg Dist:    76.73 pixels
#
# New best model PCK: 0.8041
# Epoch [54] Batch 0/104 | Loss: 0.00432240
# Epoch [54] Batch 50/104 | Loss: 0.00491473
# Epoch [54] Batch 100/104 | Loss: 0.00453463
# Epoch [54/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8055 (80.55%)
#   Val Avg Dist:    76.18 pixels
#
# New best model PCK: 0.8055
# Epoch [55] Batch 0/104 | Loss: 0.00434421
# Epoch [55] Batch 50/104 | Loss: 0.00484956
# Epoch [55] Batch 100/104 | Loss: 0.00447128
# Epoch [55/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8070 (80.70%)
#   Val Avg Dist:    75.72 pixels
#
# New best model PCK: 0.8070
# Epoch [56] Batch 0/104 | Loss: 0.00416680
# Epoch [56] Batch 50/104 | Loss: 0.00492371
# Epoch [56] Batch 100/104 | Loss: 0.00468549
# Epoch [56/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8068 (80.68%)
#   Val Avg Dist:    76.04 pixels
#
# Epoch [57] Batch 0/104 | Loss: 0.00420086
# Epoch [57] Batch 50/104 | Loss: 0.00470964
# Epoch [57] Batch 100/104 | Loss: 0.00442732
# Epoch [57/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8092 (80.92%)
#   Val Avg Dist:    75.46 pixels
#
# New best model PCK: 0.8092
# Epoch [58] Batch 0/104 | Loss: 0.00426146
# Epoch [58] Batch 50/104 | Loss: 0.00485919
# Epoch [58] Batch 100/104 | Loss: 0.00447832
# Epoch [58/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8117 (81.17%)
#   Val Avg Dist:    74.48 pixels
#
# New best model PCK: 0.8117
# Epoch [59] Batch 0/104 | Loss: 0.00428803
# Epoch [59] Batch 50/104 | Loss: 0.00485931
# Epoch [59] Batch 100/104 | Loss: 0.00456177
# Epoch [59/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8115 (81.15%)
#   Val Avg Dist:    74.60 pixels
#
# Epoch [60] Batch 0/104 | Loss: 0.00407849
# Epoch [60] Batch 50/104 | Loss: 0.00472321
# Epoch [60] Batch 100/104 | Loss: 0.00455276
# Epoch [60/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8130 (81.30%)
#   Val Avg Dist:    74.07 pixels
#
# New best model PCK: 0.8130
# Metrics plot saved to '{save_path}'
# Epoch [61] Batch 0/104 | Loss: 0.00419026
# Epoch [61] Batch 50/104 | Loss: 0.00488693
# Epoch [61] Batch 100/104 | Loss: 0.00465753
# Epoch [61/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0043
#   Val PCK@0.05:    0.8115 (81.15%)
#   Val Avg Dist:    74.41 pixels
#
# Epoch [62] Batch 0/104 | Loss: 0.00427460
# Epoch [62] Batch 50/104 | Loss: 0.00484951
# Epoch [62] Batch 100/104 | Loss: 0.00458921
# Epoch [62/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8170 (81.70%)
#   Val Avg Dist:    73.05 pixels
#
# New best model PCK: 0.8170
# Epoch [63] Batch 0/104 | Loss: 0.00417620
# Epoch [63] Batch 50/104 | Loss: 0.00485004
# Epoch [63] Batch 100/104 | Loss: 0.00447803
# Epoch [63/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8138 (81.38%)
#   Val Avg Dist:    73.46 pixels
#
# Epoch [64] Batch 0/104 | Loss: 0.00426094
# Epoch [64] Batch 50/104 | Loss: 0.00496927
# Epoch [64] Batch 100/104 | Loss: 0.00461717
# Epoch [64/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8159 (81.59%)
#   Val Avg Dist:    73.09 pixels
#
# Epoch [65] Batch 0/104 | Loss: 0.00419717
# Epoch [65] Batch 50/104 | Loss: 0.00490881
# Epoch [65] Batch 100/104 | Loss: 0.00451364
# Epoch [65/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8188 (81.88%)
#   Val Avg Dist:    72.12 pixels
#
# New best model PCK: 0.8188
# Epoch [66] Batch 0/104 | Loss: 0.00400580
# Epoch [66] Batch 50/104 | Loss: 0.00480008
# Epoch [66] Batch 100/104 | Loss: 0.00451001
# Epoch [66/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8198 (81.98%)
#   Val Avg Dist:    71.24 pixels
#
# New best model PCK: 0.8198
# Epoch [67] Batch 0/104 | Loss: 0.00408652
# Epoch [67] Batch 50/104 | Loss: 0.00490380
# Epoch [67] Batch 100/104 | Loss: 0.00447785
# Epoch [67/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8200 (82.00%)
#   Val Avg Dist:    72.04 pixels
#
# New best model PCK: 0.8200
# Epoch [68] Batch 0/104 | Loss: 0.00420806
# Epoch [68] Batch 50/104 | Loss: 0.00474221
# Epoch [68] Batch 100/104 | Loss: 0.00451278
# Epoch [68/100]:
#   Train Loss:      0.0046
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8186 (81.86%)
#   Val Avg Dist:    71.75 pixels
#
# Epoch [69] Batch 0/104 | Loss: 0.00405927
# Epoch [69] Batch 50/104 | Loss: 0.00470065
# Epoch [69] Batch 100/104 | Loss: 0.00456960
# Epoch [69/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8226 (82.26%)
#   Val Avg Dist:    70.81 pixels
#
# New best model PCK: 0.8226
# Epoch [70] Batch 0/104 | Loss: 0.00401881
# Epoch [70] Batch 50/104 | Loss: 0.00476824
# Epoch [70] Batch 100/104 | Loss: 0.00449093
# Epoch [70/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8234 (82.34%)
#   Val Avg Dist:    70.52 pixels
#
# New best model PCK: 0.8234
# Metrics plot saved to '{save_path}'
# Epoch [71] Batch 0/104 | Loss: 0.00418197
# Epoch [71] Batch 50/104 | Loss: 0.00480756
# Epoch [71] Batch 100/104 | Loss: 0.00449598
# Epoch [71/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8198 (81.98%)
#   Val Avg Dist:    71.52 pixels
#
# Epoch [72] Batch 0/104 | Loss: 0.00419216
# Epoch [72] Batch 50/104 | Loss: 0.00468041
# Epoch [72] Batch 100/104 | Loss: 0.00451881
# Epoch [72/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0041
#   Val PCK@0.05:    0.8229 (82.29%)
#   Val Avg Dist:    70.79 pixels
#
# Epoch [73] Batch 0/104 | Loss: 0.00403800
# Epoch [73] Batch 50/104 | Loss: 0.00471011
# Epoch [73] Batch 100/104 | Loss: 0.00445795
# Epoch [73/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0041
#   Val PCK@0.05:    0.8263 (82.63%)
#   Val Avg Dist:    69.46 pixels
#
# New best model PCK: 0.8263
# Epoch [74] Batch 0/104 | Loss: 0.00406858
# Epoch [74] Batch 50/104 | Loss: 0.00474246
# Epoch [74] Batch 100/104 | Loss: 0.00442472
# Epoch [74/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0042
#   Val PCK@0.05:    0.8211 (82.11%)
#   Val Avg Dist:    71.02 pixels
#
# Epoch [75] Batch 0/104 | Loss: 0.00426064
# Epoch [75] Batch 50/104 | Loss: 0.00490533
# Epoch [75] Batch 100/104 | Loss: 0.00427505
# Epoch [75/100]:
#   Train Loss:      0.0045
#   Val Loss:        0.0041
#   Val PCK@0.05:    0.8262 (82.62%)
#   Val Avg Dist:    68.90 pixels
#
#
# Switching to Fine Tuning
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-2915073643.py in <cell line: 0>()
#       1 from train_keypoint_head import main
# ----> 2 main()
#
# /content/drive/MyDrive/Projects/CourtIQ/train_keypoint_head.py in main()
#     210
#     211             with torch.amp.autocast(amp_device):
# --> 212                 features = backbone(images)
#     213                 last_feat = features[-1]
#     214
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/models/_features.py in forward(self, x)
#     343
#     344     def forward(self, x) -> (List[torch.Tensor]):
# --> 345         return list(self._collect(x).values())
#     346
#     347
#
# /usr/local/lib/python3.12/dist-packages/timm/models/_features.py in _collect(self, x)
#     297                 x = module(x) if first_or_last_module else checkpoint(module, x)
#     298             else:
# --> 299                 x = module(x)
#     300
#     301             if name in self.return_layers:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/models/byobnet.py in forward(self, x)
#     491     def forward(self, x):
#     492         shortcut = x
# --> 493         x = self.conv1_1x1(x)
#     494         x = self.conv2_kxk(x)
#     495         x = self.conv2b_kxk(x)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/layers/conv_bn_act.py in forward(self, x)
#      92     def forward(self, x):
#      93         x = self.conv(x)
# ---> 94         x = self.bn(x)
#      95         aa = getattr(self, 'aa', None)
#      96         if aa is not None:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/layers/norm_act.py in forward(self, x)
#     146         )
#     147         x = self.drop(x)
# --> 148         x = self.act(x)
#     149         return x
#     150
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     470         Runs the forward pass.
#     471         """
# --> 472         return F.silu(input, inplace=self.inplace)
#     473
#     474     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in silu(input, inplace)
#    2392         return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2393     if inplace:
# -> 2394         return torch._C._nn.silu_(input)
#    2395     return torch._C._nn.silu(input)
#    2396
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.76 GiB. GPU 0 has a total capacity of 39.49 GiB of which 1.49 GiB is free. Including non-PyTorch memory, this process has 37.99 GiB memory in use. Of the allocated memory 35.57 GiB is allocated by PyTorch, and 1.91 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
