# %% [markdown]
# Dependencies

# %%
# !pip install pytorch_metric_learning albumentations

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

location = '/content/drive/MyDrive/Projects/CourtIQ/'

sys.path.append(os.path.abspath(location))

# %% [markdown]
# Unzip Dataset

# %%
# !unzip -u /content/drive/MyDrive/Projects/CourtIQ/tennis_court_det_dataset.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/data/images/JNKp7sCdQlY_2200.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_2250.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_250.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_300.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_350.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_400.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_450.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_50.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_500.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_550.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_600.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_650.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_700.png
#   inflating: /content/data/data/images/JNKp7sCdQlY_750.png
#   inflating: /content/data/data/images/juXbdW7z0WA_100.png
# ...

# %% [markdown]
# Train

# %%
from fine_tune_backbone_with_keypoint_head import main
main()

from google.colab import runtime
runtime.unassign()
# Out:
# Training on cuda
# Stride: 32
# Loaded keypoint head weights
# Training samples: 6630
# Validation samples: 2211
# Batch 0/208 | Loss: 0.0048
# Batch 50/208 | Loss: 0.0032
# Batch 100/208 | Loss: 0.0024
# Batch 150/208 | Loss: 0.0020
# Batch 200/208 | Loss: 0.0021
# Epoch [1/50]:
#   Train Loss:      0.0027
#   Val Loss:        0.0008
#   Val PCK@0.05:    0.9916 (99.16%)
#   Val Avg Dist:    13.43 pixels
#
# New best model PCK: 0.9916
# Batch 0/208 | Loss: 0.0020
# Batch 50/208 | Loss: 0.0015
# Batch 100/208 | Loss: 0.0012
# Batch 150/208 | Loss: 0.0013
# Batch 200/208 | Loss: 0.0014
# Epoch [2/50]:
#   Train Loss:      0.0015
#   Val Loss:        0.0005
#   Val PCK@0.05:    0.9946 (99.46%)
#   Val Avg Dist:    10.16 pixels
#
# New best model PCK: 0.9946
# Batch 0/208 | Loss: 0.0016
# Batch 50/208 | Loss: 0.0012
# Batch 100/208 | Loss: 0.0008
# Batch 150/208 | Loss: 0.0010
# Batch 200/208 | Loss: 0.0012
# Epoch [3/50]:
#   Train Loss:      0.0012
#   Val Loss:        0.0003
# ...
